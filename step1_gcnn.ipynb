# %%
# Import package
import numpy as np
import random
from numpy.core.numeric import ones_like
from torch_geometric.data import Data, DataLoader
import torch
from tqdm import tqdm
from utils.debruijn import DeBruijnGraph

# %%
# Define tf and datapaths
TF = 'ctcf'

PATH_ = "/DATA/yogesh/encodeDream/%s/"%(TF)
# Using readlines()
file1 = open(PATH_+'processed_out/final_training.csv', 'r')
Lines = file1.readlines()

# %%
# Visualize the distribution of +ve samples in data
all_pos = []
window = []
for i in tqdm(range(0,len(Lines),1000000)):
    pos = 0
    for line in Lines[i:i+1000000]:
        if line.strip().split(',')[1]=='B':
            pos+=1
    all_pos.append(pos)
    window.append(str(int(i/1000000))+':'+str(int(i/1000000+10)))
    
import matplotlib.pyplot as plt
plt.bar(window, all_pos)
plt.ylabel('Number of bound datapoints')
plt.xlabel('Datapoint window (in lacs)')
plt.xticks(rotation=90)

plt.show()

# %%
# Sample +ve and -ve samples from data
DATAPOINTS = 200000
count_b, count_u = 0, 0
op = open(PATH_+'processed_out/balanced_training.csv',"w")
    
for line in tqdm(Lines):
    if line.strip().split(',')[1]=='B':
        count_b+=1
        op.write(line)
    
    if count_b>int(DATAPOINTS*0.2):
        break
        
for line in tqdm(Lines):
    if line.strip().split(',')[1]=='U':
        count_u+=1
        op.write(line)
    if count_u>int(DATAPOINTS*0.8):
        break
# Out:
#   9%|▊         | 4071330/47549176 [00:04<00:43, 1008649.20it/s]
#   0%|          | 160891/47549176 [00:00<01:08, 688099.90it/s]

# %%
# Import balanced data
file1 = open(PATH_+'processed_out/balanced_training.csv', 'r')
Lines = file1.readlines()

# %%
# Prepare Data
kmer, DATALIST = 5, []
counter = 0
for line in tqdm(Lines):
    onehot_x = []
    # get DNA sequence from the dummy file 
    s = line.strip().split(',')[0]
    d=DeBruijnGraph(s,kmer)    
    for node in d.x.flatten():
        one_hot_ = d.one_hot_encode(node).flatten()
        onehot_x.append(one_hot_.tolist())

    # Arrays to pytorch tensors
    onehot_x_tensor = torch.tensor(np.array(onehot_x), dtype=torch.float)
    onehot_edge_index_tensor = torch.tensor(d.edge_index, dtype=torch.long)
    
    # get the label from the data
    if line.strip().split(',')[1]=='U':
        y_tensor = torch.tensor(0)
    else:
        y_tensor = torch.tensor(1)

    # Add tensors to torch_geometric data object
    data = Data(x=onehot_x_tensor, edge_index=onehot_edge_index_tensor, y=y_tensor)

    DATALIST.append(data)
    counter+=1
    if counter>=300000:
        break
# Out:
# 100%|██████████| 199998/199998 [24:51<00:00, 134.12it/s]

# %%
print('Datapoints:', len(DATALIST))

print('x_shape:', DATALIST[1].x.shape)
print('edge_index_shape:', DATALIST[1].edge_index.shape)
print()
# Out:
# Datapoints: 199998
# x_shape: torch.Size([94, 16])
# edge_index_shape: torch.Size([2, 196])

# %%
temp_data = DATALIST[1]  # Get the first graph object.

print()
print(temp_data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {temp_data.num_nodes}')
print(f'Number of edges: {temp_data.num_edges}')
print(f'Average node degree: {temp_data.num_edges / temp_data.num_nodes:.2f}')
print(f'Contains self-loops: {temp_data.contains_self_loops()}')
print(f'Is undirected: {temp_data.is_undirected()}')
# Out:
# Data(edge_index=[2, 196], x=[94, 16], y=1)
# =============================================================
# Number of nodes: 94
# Number of edges: 196
# Average node degree: 2.09
# Contains self-loops: True
# Is undirected: False

# %%
# Split data
torch.manual_seed(11)
random.shuffle(DATALIST)

split_n = int(0.8*(len(DATALIST)))

train_dataset = DATALIST[:split_n]
test_dataset = DATALIST[split_n:]

print('Number of training graph:', len(train_dataset))
print('Number of testing graph:', len(test_dataset))
# Out:
# Number of training graph: 159998
# Number of testing graph: 40000

# %%
#####
from torch_geometric.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=True)

for step, data in enumerate(train_loader):
    print(f'Step {step+1}:')
    print('=====')
    print(f'Number of graphs in current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60305], edge_index=[2, 100352], ptr=[513], x=[60305, 16], y=[512])
#
# Step 2:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60956], edge_index=[2, 100352], ptr=[513], x=[60956, 16], y=[512])
#
# Step 3:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61022], edge_index=[2, 100352], ptr=[513], x=[61022, 16], y=[512])
#
# Step 4:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61339], edge_index=[2, 100352], ptr=[513], x=[61339, 16], y=[512])
#
# Step 5:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60464], edge_index=[2, 100352], ptr=[513], x=[60464, 16], y=[512])
#
# Step 6:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61139], edge_index=[2, 100352], ptr=[513], x=[61139, 16], y=[512])
#
# Step 7:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60846], edge_index=[2, 100352], ptr=[513], x=[60846, 16], y=[512])
#
# Step 8:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60170], edge_index=[2, 100352], ptr=[513], x=[60170, 16], y=[512])
#
# Step 9:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60745], edge_index=[2, 100352], ptr=[513], x=[60745, 16], y=[512])
#
# Step 10:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60392], edge_index=[2, 100352], ptr=[513], x=[60392, 16], y=[512])
#
# Step 11:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60602], edge_index=[2, 100352], ptr=[513], x=[60602, 16], y=[512])
#
# Step 12:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60790], edge_index=[2, 100352], ptr=[513], x=[60790, 16], y=[512])
#
# Step 13:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60771], edge_index=[2, 100352], ptr=[513], x=[60771, 16], y=[512])
#
# Step 14:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60451], edge_index=[2, 100352], ptr=[513], x=[60451, 16], y=[512])
#
# Step 15:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60597], edge_index=[2, 100352], ptr=[513], x=[60597, 16], y=[512])
#
# Step 16:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60950], edge_index=[2, 100352], ptr=[513], x=[60950, 16], y=[512])
#
# Step 17:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60654], edge_index=[2, 100352], ptr=[513], x=[60654, 16], y=[512])
#
# Step 18:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60936], edge_index=[2, 100352], ptr=[513], x=[60936, 16], y=[512])
#
# Step 19:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61145], edge_index=[2, 100352], ptr=[513], x=[61145, 16], y=[512])
#
# Step 20:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61286], edge_index=[2, 100352], ptr=[513], x=[61286, 16], y=[512])
#
# Step 21:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61238], edge_index=[2, 100352], ptr=[513], x=[61238, 16], y=[512])
#
# Step 22:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60517], edge_index=[2, 100352], ptr=[513], x=[60517, 16], y=[512])
#
# Step 23:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60940], edge_index=[2, 100352], ptr=[513], x=[60940, 16], y=[512])
#
# Step 24:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60283], edge_index=[2, 100352], ptr=[513], x=[60283, 16], y=[512])
#
# Step 25:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61075], edge_index=[2, 100352], ptr=[513], x=[61075, 16], y=[512])
#
# Step 26:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60542], edge_index=[2, 100352], ptr=[513], x=[60542, 16], y=[512])
#
# Step 27:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60402], edge_index=[2, 100352], ptr=[513], x=[60402, 16], y=[512])
#
# Step 28:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60711], edge_index=[2, 100352], ptr=[513], x=[60711, 16], y=[512])
#
# Step 29:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60552], edge_index=[2, 100352], ptr=[513], x=[60552, 16], y=[512])
#
# Step 30:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60465], edge_index=[2, 100352], ptr=[513], x=[60465, 16], y=[512])
#
# Step 31:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60547], edge_index=[2, 100352], ptr=[513], x=[60547, 16], y=[512])
#
# Step 32:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60415], edge_index=[2, 100352], ptr=[513], x=[60415, 16], y=[512])
#
# Step 33:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60953], edge_index=[2, 100352], ptr=[513], x=[60953, 16], y=[512])
#
# Step 34:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60473], edge_index=[2, 100352], ptr=[513], x=[60473, 16], y=[512])
#
# Step 35:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60928], edge_index=[2, 100352], ptr=[513], x=[60928, 16], y=[512])
#
# Step 36:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60764], edge_index=[2, 100352], ptr=[513], x=[60764, 16], y=[512])
#
# Step 37:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61380], edge_index=[2, 100352], ptr=[513], x=[61380, 16], y=[512])
#
# Step 38:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60520], edge_index=[2, 100352], ptr=[513], x=[60520, 16], y=[512])
#
# Step 39:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60809], edge_index=[2, 100352], ptr=[513], x=[60809, 16], y=[512])
#
# Step 40:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60778], edge_index=[2, 100352], ptr=[513], x=[60778, 16], y=[512])
#
# Step 41:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60846], edge_index=[2, 100352], ptr=[513], x=[60846, 16], y=[512])
#
# Step 42:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60721], edge_index=[2, 100352], ptr=[513], x=[60721, 16], y=[512])
#
# Step 43:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60799], edge_index=[2, 100352], ptr=[513], x=[60799, 16], y=[512])
#
# Step 44:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60556], edge_index=[2, 100352], ptr=[513], x=[60556, 16], y=[512])
#
# Step 45:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61230], edge_index=[2, 100352], ptr=[513], x=[61230, 16], y=[512])
#
# Step 46:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60091], edge_index=[2, 100352], ptr=[513], x=[60091, 16], y=[512])
#
# Step 47:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60593], edge_index=[2, 100352], ptr=[513], x=[60593, 16], y=[512])
#
# Step 48:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61272], edge_index=[2, 100352], ptr=[513], x=[61272, 16], y=[512])
#
# Step 49:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60592], edge_index=[2, 100352], ptr=[513], x=[60592, 16], y=[512])
#
# Step 50:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61573], edge_index=[2, 100352], ptr=[513], x=[61573, 16], y=[512])
#
# Step 51:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61115], edge_index=[2, 100352], ptr=[513], x=[61115, 16], y=[512])
#
# Step 52:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60544], edge_index=[2, 100352], ptr=[513], x=[60544, 16], y=[512])
#
# Step 53:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60314], edge_index=[2, 100352], ptr=[513], x=[60314, 16], y=[512])
#
# Step 54:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61082], edge_index=[2, 100352], ptr=[513], x=[61082, 16], y=[512])
#
# Step 55:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60869], edge_index=[2, 100352], ptr=[513], x=[60869, 16], y=[512])
#
# Step 56:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60403], edge_index=[2, 100352], ptr=[513], x=[60403, 16], y=[512])
#
# Step 57:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60982], edge_index=[2, 100352], ptr=[513], x=[60982, 16], y=[512])
#
# Step 58:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60669], edge_index=[2, 100352], ptr=[513], x=[60669, 16], y=[512])
#
# Step 59:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61470], edge_index=[2, 100352], ptr=[513], x=[61470, 16], y=[512])
#
# Step 60:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60910], edge_index=[2, 100352], ptr=[513], x=[60910, 16], y=[512])
#
# Step 61:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60814], edge_index=[2, 100352], ptr=[513], x=[60814, 16], y=[512])
#
# Step 62:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60569], edge_index=[2, 100352], ptr=[513], x=[60569, 16], y=[512])
# Step 63:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60786], edge_index=[2, 100352], ptr=[513], x=[60786, 16], y=[512])
#
# Step 64:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60727], edge_index=[2, 100352], ptr=[513], x=[60727, 16], y=[512])
#
# Step 65:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60720], edge_index=[2, 100352], ptr=[513], x=[60720, 16], y=[512])
#
# Step 66:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60586], edge_index=[2, 100352], ptr=[513], x=[60586, 16], y=[512])
#
# Step 67:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61119], edge_index=[2, 100352], ptr=[513], x=[61119, 16], y=[512])
#
# Step 68:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60707], edge_index=[2, 100352], ptr=[513], x=[60707, 16], y=[512])
#
# Step 69:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60496], edge_index=[2, 100352], ptr=[513], x=[60496, 16], y=[512])
#
# Step 70:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61317], edge_index=[2, 100352], ptr=[513], x=[61317, 16], y=[512])
#
# Step 71:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[59817], edge_index=[2, 100352], ptr=[513], x=[59817, 16], y=[512])
#
# Step 72:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60459], edge_index=[2, 100352], ptr=[513], x=[60459, 16], y=[512])
#
# Step 73:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60729], edge_index=[2, 100352], ptr=[513], x=[60729, 16], y=[512])
#
# Step 74:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61167], edge_index=[2, 100352], ptr=[513], x=[61167, 16], y=[512])
#
# Step 75:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60416], edge_index=[2, 100352], ptr=[513], x=[60416, 16], y=[512])
#
# Step 76:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60058], edge_index=[2, 100352], ptr=[513], x=[60058, 16], y=[512])
#
# Step 77:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60697], edge_index=[2, 100352], ptr=[513], x=[60697, 16], y=[512])
#
# Step 78:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60718], edge_index=[2, 100352], ptr=[513], x=[60718, 16], y=[512])
#
# Step 79:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60545], edge_index=[2, 100352], ptr=[513], x=[60545, 16], y=[512])
#
# Step 80:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60683], edge_index=[2, 100352], ptr=[513], x=[60683, 16], y=[512])
#
# Step 81:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60301], edge_index=[2, 100352], ptr=[513], x=[60301, 16], y=[512])
#
# Step 82:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61236], edge_index=[2, 100352], ptr=[513], x=[61236, 16], y=[512])
#
# Step 83:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61239], edge_index=[2, 100352], ptr=[513], x=[61239, 16], y=[512])
#
# Step 84:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60842], edge_index=[2, 100352], ptr=[513], x=[60842, 16], y=[512])
#
# Step 85:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60931], edge_index=[2, 100352], ptr=[513], x=[60931, 16], y=[512])
#
# Step 86:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61049], edge_index=[2, 100352], ptr=[513], x=[61049, 16], y=[512])
#
# Step 87:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60568], edge_index=[2, 100352], ptr=[513], x=[60568, 16], y=[512])
#
# Step 88:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60829], edge_index=[2, 100352], ptr=[513], x=[60829, 16], y=[512])
#
# Step 89:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61011], edge_index=[2, 100352], ptr=[513], x=[61011, 16], y=[512])
#
# Step 90:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60978], edge_index=[2, 100352], ptr=[513], x=[60978, 16], y=[512])
#
# Step 91:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60778], edge_index=[2, 100352], ptr=[513], x=[60778, 16], y=[512])
#
# Step 92:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60595], edge_index=[2, 100352], ptr=[513], x=[60595, 16], y=[512])
#
# Step 93:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61266], edge_index=[2, 100352], ptr=[513], x=[61266, 16], y=[512])
#
# Step 94:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60258], edge_index=[2, 100352], ptr=[513], x=[60258, 16], y=[512])
#
# Step 95:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60220], edge_index=[2, 100352], ptr=[513], x=[60220, 16], y=[512])
#
# Step 96:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60395], edge_index=[2, 100352], ptr=[513], x=[60395, 16], y=[512])
#
# Step 97:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60416], edge_index=[2, 100352], ptr=[513], x=[60416, 16], y=[512])
#
# Step 98:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60961], edge_index=[2, 100352], ptr=[513], x=[60961, 16], y=[512])
#
# Step 99:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60956], edge_index=[2, 100352], ptr=[513], x=[60956, 16], y=[512])
#
# Step 100:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60715], edge_index=[2, 100352], ptr=[513], x=[60715, 16], y=[512])
#
# Step 101:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60487], edge_index=[2, 100352], ptr=[513], x=[60487, 16], y=[512])
#
# Step 102:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60786], edge_index=[2, 100352], ptr=[513], x=[60786, 16], y=[512])
#
# Step 103:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60718], edge_index=[2, 100352], ptr=[513], x=[60718, 16], y=[512])
#
# Step 104:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61124], edge_index=[2, 100352], ptr=[513], x=[61124, 16], y=[512])
#
# Step 105:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60806], edge_index=[2, 100352], ptr=[513], x=[60806, 16], y=[512])
#
# Step 106:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60468], edge_index=[2, 100352], ptr=[513], x=[60468, 16], y=[512])
#
# Step 107:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61314], edge_index=[2, 100352], ptr=[513], x=[61314, 16], y=[512])
#
# Step 108:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60418], edge_index=[2, 100352], ptr=[513], x=[60418, 16], y=[512])
#
# Step 109:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60579], edge_index=[2, 100352], ptr=[513], x=[60579, 16], y=[512])
#
# Step 110:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60643], edge_index=[2, 100352], ptr=[513], x=[60643, 16], y=[512])
#
# Step 111:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60272], edge_index=[2, 100352], ptr=[513], x=[60272, 16], y=[512])
#
# Step 112:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60186], edge_index=[2, 100352], ptr=[513], x=[60186, 16], y=[512])
#
# Step 113:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60605], edge_index=[2, 100352], ptr=[513], x=[60605, 16], y=[512])
#
# Step 114:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60909], edge_index=[2, 100352], ptr=[513], x=[60909, 16], y=[512])
#
# Step 115:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60421], edge_index=[2, 100352], ptr=[513], x=[60421, 16], y=[512])
#
# Step 116:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60825], edge_index=[2, 100352], ptr=[513], x=[60825, 16], y=[512])
#
# Step 117:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61037], edge_index=[2, 100352], ptr=[513], x=[61037, 16], y=[512])
#
# Step 118:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60598], edge_index=[2, 100352], ptr=[513], x=[60598, 16], y=[512])
#
# Step 119:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61122], edge_index=[2, 100352], ptr=[513], x=[61122, 16], y=[512])
#
# Step 120:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61130], edge_index=[2, 100352], ptr=[513], x=[61130, 16], y=[512])
#
# Step 121:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60496], edge_index=[2, 100352], ptr=[513], x=[60496, 16], y=[512])
#
# Step 122:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60737], edge_index=[2, 100352], ptr=[513], x=[60737, 16], y=[512])
#
# Step 123:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60884], edge_index=[2, 100352], ptr=[513], x=[60884, 16], y=[512])
#
# Step 124:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60904], edge_index=[2, 100352], ptr=[513], x=[60904, 16], y=[512])
#
# Step 125:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61088], edge_index=[2, 100352], ptr=[513], x=[61088, 16], y=[512])
# Step 126:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60762], edge_index=[2, 100352], ptr=[513], x=[60762, 16], y=[512])
#
# Step 127:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60508], edge_index=[2, 100352], ptr=[513], x=[60508, 16], y=[512])
#
# Step 128:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60979], edge_index=[2, 100352], ptr=[513], x=[60979, 16], y=[512])
#
# Step 129:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60361], edge_index=[2, 100352], ptr=[513], x=[60361, 16], y=[512])
#
# Step 130:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60363], edge_index=[2, 100352], ptr=[513], x=[60363, 16], y=[512])
#
# Step 131:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61243], edge_index=[2, 100352], ptr=[513], x=[61243, 16], y=[512])
#
# Step 132:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60755], edge_index=[2, 100352], ptr=[513], x=[60755, 16], y=[512])
#
# Step 133:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60695], edge_index=[2, 100352], ptr=[513], x=[60695, 16], y=[512])
#
# Step 134:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60815], edge_index=[2, 100352], ptr=[513], x=[60815, 16], y=[512])
#
# Step 135:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60891], edge_index=[2, 100352], ptr=[513], x=[60891, 16], y=[512])
#
# Step 136:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61046], edge_index=[2, 100352], ptr=[513], x=[61046, 16], y=[512])
#
# Step 137:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60130], edge_index=[2, 100352], ptr=[513], x=[60130, 16], y=[512])
#
# Step 138:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60165], edge_index=[2, 100352], ptr=[513], x=[60165, 16], y=[512])
#
# Step 139:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61330], edge_index=[2, 100352], ptr=[513], x=[61330, 16], y=[512])
#
# Step 140:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60701], edge_index=[2, 100352], ptr=[513], x=[60701, 16], y=[512])
#
# Step 141:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60864], edge_index=[2, 100352], ptr=[513], x=[60864, 16], y=[512])
#
# Step 142:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60652], edge_index=[2, 100352], ptr=[513], x=[60652, 16], y=[512])
#
# Step 143:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60590], edge_index=[2, 100352], ptr=[513], x=[60590, 16], y=[512])
#
# Step 144:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60259], edge_index=[2, 100352], ptr=[513], x=[60259, 16], y=[512])
#
# Step 145:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60198], edge_index=[2, 100352], ptr=[513], x=[60198, 16], y=[512])
#
# Step 146:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60804], edge_index=[2, 100352], ptr=[513], x=[60804, 16], y=[512])
#
# Step 147:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61083], edge_index=[2, 100352], ptr=[513], x=[61083, 16], y=[512])
#
# Step 148:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60246], edge_index=[2, 100352], ptr=[513], x=[60246, 16], y=[512])
#
# Step 149:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61457], edge_index=[2, 100352], ptr=[513], x=[61457, 16], y=[512])
#
# Step 150:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60558], edge_index=[2, 100352], ptr=[513], x=[60558, 16], y=[512])
#
# Step 151:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60893], edge_index=[2, 100352], ptr=[513], x=[60893, 16], y=[512])
#
# Step 152:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61210], edge_index=[2, 100352], ptr=[513], x=[61210, 16], y=[512])
#
# Step 153:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61220], edge_index=[2, 100352], ptr=[513], x=[61220, 16], y=[512])
#
# Step 154:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60728], edge_index=[2, 100352], ptr=[513], x=[60728, 16], y=[512])
#
# Step 155:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60732], edge_index=[2, 100352], ptr=[513], x=[60732, 16], y=[512])
#
# Step 156:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60623], edge_index=[2, 100352], ptr=[513], x=[60623, 16], y=[512])
#
# Step 157:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60835], edge_index=[2, 100352], ptr=[513], x=[60835, 16], y=[512])
#
# Step 158:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60935], edge_index=[2, 100352], ptr=[513], x=[60935, 16], y=[512])
#
# Step 159:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60888], edge_index=[2, 100352], ptr=[513], x=[60888, 16], y=[512])
#
# Step 160:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60949], edge_index=[2, 100352], ptr=[513], x=[60949, 16], y=[512])
#
# Step 161:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60751], edge_index=[2, 100352], ptr=[513], x=[60751, 16], y=[512])
#
# Step 162:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60227], edge_index=[2, 100352], ptr=[513], x=[60227, 16], y=[512])
#
# Step 163:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60519], edge_index=[2, 100352], ptr=[513], x=[60519, 16], y=[512])
#
# Step 164:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60596], edge_index=[2, 100352], ptr=[513], x=[60596, 16], y=[512])
#
# Step 165:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61122], edge_index=[2, 100352], ptr=[513], x=[61122, 16], y=[512])
#
# Step 166:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60581], edge_index=[2, 100352], ptr=[513], x=[60581, 16], y=[512])
#
# Step 167:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61561], edge_index=[2, 100352], ptr=[513], x=[61561, 16], y=[512])
#
# Step 168:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60060], edge_index=[2, 100352], ptr=[513], x=[60060, 16], y=[512])
#
# Step 169:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60470], edge_index=[2, 100352], ptr=[513], x=[60470, 16], y=[512])
#
# Step 170:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60475], edge_index=[2, 100352], ptr=[513], x=[60475, 16], y=[512])
#
# Step 171:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60578], edge_index=[2, 100352], ptr=[513], x=[60578, 16], y=[512])
#
# Step 172:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60692], edge_index=[2, 100352], ptr=[513], x=[60692, 16], y=[512])
#
# Step 173:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60929], edge_index=[2, 100352], ptr=[513], x=[60929, 16], y=[512])
#
# Step 174:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60672], edge_index=[2, 100352], ptr=[513], x=[60672, 16], y=[512])
#
# Step 175:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60277], edge_index=[2, 100352], ptr=[513], x=[60277, 16], y=[512])
#
# Step 176:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60859], edge_index=[2, 100352], ptr=[513], x=[60859, 16], y=[512])
#
# Step 177:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60576], edge_index=[2, 100352], ptr=[513], x=[60576, 16], y=[512])
#
# Step 178:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60741], edge_index=[2, 100352], ptr=[513], x=[60741, 16], y=[512])
#
# Step 179:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60752], edge_index=[2, 100352], ptr=[513], x=[60752, 16], y=[512])
#
# Step 180:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60718], edge_index=[2, 100352], ptr=[513], x=[60718, 16], y=[512])
#
# Step 181:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61089], edge_index=[2, 100352], ptr=[513], x=[61089, 16], y=[512])
#
# Step 182:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60562], edge_index=[2, 100352], ptr=[513], x=[60562, 16], y=[512])
#
# Step 183:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61141], edge_index=[2, 100352], ptr=[513], x=[61141, 16], y=[512])
#
# Step 184:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60912], edge_index=[2, 100352], ptr=[513], x=[60912, 16], y=[512])
#
# Step 185:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60863], edge_index=[2, 100352], ptr=[513], x=[60863, 16], y=[512])
#
# Step 186:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61106], edge_index=[2, 100352], ptr=[513], x=[61106, 16], y=[512])
# Step 187:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60450], edge_index=[2, 100352], ptr=[513], x=[60450, 16], y=[512])
#
# Step 188:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60496], edge_index=[2, 100352], ptr=[513], x=[60496, 16], y=[512])
#
# Step 189:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61213], edge_index=[2, 100352], ptr=[513], x=[61213, 16], y=[512])
#
# Step 190:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60636], edge_index=[2, 100352], ptr=[513], x=[60636, 16], y=[512])
#
# Step 191:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60837], edge_index=[2, 100352], ptr=[513], x=[60837, 16], y=[512])
#
# Step 192:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60163], edge_index=[2, 100352], ptr=[513], x=[60163, 16], y=[512])
#
# Step 193:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60655], edge_index=[2, 100352], ptr=[513], x=[60655, 16], y=[512])
#
# Step 194:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61427], edge_index=[2, 100352], ptr=[513], x=[61427, 16], y=[512])
#
# Step 195:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60974], edge_index=[2, 100352], ptr=[513], x=[60974, 16], y=[512])
#
# Step 196:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61562], edge_index=[2, 100352], ptr=[513], x=[61562, 16], y=[512])
#
# Step 197:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60876], edge_index=[2, 100352], ptr=[513], x=[60876, 16], y=[512])
#
# Step 198:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61143], edge_index=[2, 100352], ptr=[513], x=[61143, 16], y=[512])
#
# Step 199:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60983], edge_index=[2, 100352], ptr=[513], x=[60983, 16], y=[512])
#
# Step 200:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60519], edge_index=[2, 100352], ptr=[513], x=[60519, 16], y=[512])
#
# Step 201:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61385], edge_index=[2, 100352], ptr=[513], x=[61385, 16], y=[512])
#
# Step 202:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60828], edge_index=[2, 100352], ptr=[513], x=[60828, 16], y=[512])
#
# Step 203:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60203], edge_index=[2, 100352], ptr=[513], x=[60203, 16], y=[512])
#
# Step 204:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60805], edge_index=[2, 100352], ptr=[513], x=[60805, 16], y=[512])
#
# Step 205:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60746], edge_index=[2, 100352], ptr=[513], x=[60746, 16], y=[512])
#
# Step 206:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61154], edge_index=[2, 100352], ptr=[513], x=[61154, 16], y=[512])
#
# Step 207:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60731], edge_index=[2, 100352], ptr=[513], x=[60731, 16], y=[512])
#
# Step 208:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60618], edge_index=[2, 100352], ptr=[513], x=[60618, 16], y=[512])
#
# Step 209:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60489], edge_index=[2, 100352], ptr=[513], x=[60489, 16], y=[512])
#
# Step 210:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60572], edge_index=[2, 100352], ptr=[513], x=[60572, 16], y=[512])
#
# Step 211:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60805], edge_index=[2, 100352], ptr=[513], x=[60805, 16], y=[512])
#
# Step 212:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60803], edge_index=[2, 100352], ptr=[513], x=[60803, 16], y=[512])
#
# Step 213:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60215], edge_index=[2, 100352], ptr=[513], x=[60215, 16], y=[512])
#
# Step 214:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61048], edge_index=[2, 100352], ptr=[513], x=[61048, 16], y=[512])
#
# Step 215:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60675], edge_index=[2, 100352], ptr=[513], x=[60675, 16], y=[512])
#
# Step 216:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60819], edge_index=[2, 100352], ptr=[513], x=[60819, 16], y=[512])
#
# Step 217:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61368], edge_index=[2, 100352], ptr=[513], x=[61368, 16], y=[512])
#
# Step 218:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60770], edge_index=[2, 100352], ptr=[513], x=[60770, 16], y=[512])
#
# Step 219:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60727], edge_index=[2, 100352], ptr=[513], x=[60727, 16], y=[512])
#
# Step 220:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60459], edge_index=[2, 100352], ptr=[513], x=[60459, 16], y=[512])
#
# Step 221:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60576], edge_index=[2, 100352], ptr=[513], x=[60576, 16], y=[512])
#
# Step 222:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60161], edge_index=[2, 100352], ptr=[513], x=[60161, 16], y=[512])
#
# Step 223:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60447], edge_index=[2, 100352], ptr=[513], x=[60447, 16], y=[512])
#
# Step 224:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60325], edge_index=[2, 100352], ptr=[513], x=[60325, 16], y=[512])
#
# Step 225:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61146], edge_index=[2, 100352], ptr=[513], x=[61146, 16], y=[512])
#
# Step 226:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60570], edge_index=[2, 100352], ptr=[513], x=[60570, 16], y=[512])
#
# Step 227:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61569], edge_index=[2, 100352], ptr=[513], x=[61569, 16], y=[512])
#
# Step 228:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61264], edge_index=[2, 100352], ptr=[513], x=[61264, 16], y=[512])
#
# Step 229:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60517], edge_index=[2, 100352], ptr=[513], x=[60517, 16], y=[512])
#
# Step 230:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61190], edge_index=[2, 100352], ptr=[513], x=[61190, 16], y=[512])
#
# Step 231:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61042], edge_index=[2, 100352], ptr=[513], x=[61042, 16], y=[512])
#
# Step 232:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60324], edge_index=[2, 100352], ptr=[513], x=[60324, 16], y=[512])
#
# Step 233:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60351], edge_index=[2, 100352], ptr=[513], x=[60351, 16], y=[512])
#
# Step 234:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60708], edge_index=[2, 100352], ptr=[513], x=[60708, 16], y=[512])
#
# Step 235:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61242], edge_index=[2, 100352], ptr=[513], x=[61242, 16], y=[512])
#
# Step 236:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60810], edge_index=[2, 100352], ptr=[513], x=[60810, 16], y=[512])
#
# Step 237:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60353], edge_index=[2, 100352], ptr=[513], x=[60353, 16], y=[512])
#
# Step 238:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60364], edge_index=[2, 100352], ptr=[513], x=[60364, 16], y=[512])
#
# Step 239:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61244], edge_index=[2, 100352], ptr=[513], x=[61244, 16], y=[512])
#
# Step 240:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60306], edge_index=[2, 100352], ptr=[513], x=[60306, 16], y=[512])
#
# Step 241:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60713], edge_index=[2, 100352], ptr=[513], x=[60713, 16], y=[512])
#
# Step 242:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60754], edge_index=[2, 100352], ptr=[513], x=[60754, 16], y=[512])
#
# Step 243:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60959], edge_index=[2, 100352], ptr=[513], x=[60959, 16], y=[512])
#
# Step 244:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61094], edge_index=[2, 100352], ptr=[513], x=[61094, 16], y=[512])
#
# Step 245:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60454], edge_index=[2, 100352], ptr=[513], x=[60454, 16], y=[512])
#
# Step 246:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60502], edge_index=[2, 100352], ptr=[513], x=[60502, 16], y=[512])
#
# Step 247:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60714], edge_index=[2, 100352], ptr=[513], x=[60714, 16], y=[512])
# Step 248:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60952], edge_index=[2, 100352], ptr=[513], x=[60952, 16], y=[512])
#
# Step 249:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60833], edge_index=[2, 100352], ptr=[513], x=[60833, 16], y=[512])
#
# Step 250:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61364], edge_index=[2, 100352], ptr=[513], x=[61364, 16], y=[512])
#
# Step 251:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60651], edge_index=[2, 100352], ptr=[513], x=[60651, 16], y=[512])
#
# Step 252:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61006], edge_index=[2, 100352], ptr=[513], x=[61006, 16], y=[512])
#
# Step 253:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60679], edge_index=[2, 100352], ptr=[513], x=[60679, 16], y=[512])
#
# Step 254:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60469], edge_index=[2, 100352], ptr=[513], x=[60469, 16], y=[512])
#
# Step 255:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61772], edge_index=[2, 100352], ptr=[513], x=[61772, 16], y=[512])
#
# Step 256:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60697], edge_index=[2, 100352], ptr=[513], x=[60697, 16], y=[512])
#
# Step 257:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60569], edge_index=[2, 100352], ptr=[513], x=[60569, 16], y=[512])
#
# Step 258:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60804], edge_index=[2, 100352], ptr=[513], x=[60804, 16], y=[512])
#
# Step 259:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60585], edge_index=[2, 100352], ptr=[513], x=[60585, 16], y=[512])
#
# Step 260:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60643], edge_index=[2, 100352], ptr=[513], x=[60643, 16], y=[512])
#
# Step 261:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60357], edge_index=[2, 100352], ptr=[513], x=[60357, 16], y=[512])
#
# Step 262:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60851], edge_index=[2, 100352], ptr=[513], x=[60851, 16], y=[512])
#
# Step 263:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60779], edge_index=[2, 100352], ptr=[513], x=[60779, 16], y=[512])
#
# Step 264:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60833], edge_index=[2, 100352], ptr=[513], x=[60833, 16], y=[512])
#
# Step 265:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60707], edge_index=[2, 100352], ptr=[513], x=[60707, 16], y=[512])
#
# Step 266:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61034], edge_index=[2, 100352], ptr=[513], x=[61034, 16], y=[512])
#
# Step 267:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61201], edge_index=[2, 100352], ptr=[513], x=[61201, 16], y=[512])
#
# Step 268:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60704], edge_index=[2, 100352], ptr=[513], x=[60704, 16], y=[512])
#
# Step 269:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60303], edge_index=[2, 100352], ptr=[513], x=[60303, 16], y=[512])
#
# Step 270:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60394], edge_index=[2, 100352], ptr=[513], x=[60394, 16], y=[512])
#
# Step 271:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60663], edge_index=[2, 100352], ptr=[513], x=[60663, 16], y=[512])
#
# Step 272:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60709], edge_index=[2, 100352], ptr=[513], x=[60709, 16], y=[512])
#
# Step 273:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60972], edge_index=[2, 100352], ptr=[513], x=[60972, 16], y=[512])
#
# Step 274:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60880], edge_index=[2, 100352], ptr=[513], x=[60880, 16], y=[512])
#
# Step 275:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60898], edge_index=[2, 100352], ptr=[513], x=[60898, 16], y=[512])
#
# Step 276:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60364], edge_index=[2, 100352], ptr=[513], x=[60364, 16], y=[512])
#
# Step 277:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60503], edge_index=[2, 100352], ptr=[513], x=[60503, 16], y=[512])
#
# Step 278:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60677], edge_index=[2, 100352], ptr=[513], x=[60677, 16], y=[512])
#
# Step 279:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60638], edge_index=[2, 100352], ptr=[513], x=[60638, 16], y=[512])
#
# Step 280:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61294], edge_index=[2, 100352], ptr=[513], x=[61294, 16], y=[512])
#
# Step 281:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60651], edge_index=[2, 100352], ptr=[513], x=[60651, 16], y=[512])
#
# Step 282:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60717], edge_index=[2, 100352], ptr=[513], x=[60717, 16], y=[512])
#
# Step 283:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60085], edge_index=[2, 100352], ptr=[513], x=[60085, 16], y=[512])
#
# Step 284:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60346], edge_index=[2, 100352], ptr=[513], x=[60346, 16], y=[512])
#
# Step 285:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60303], edge_index=[2, 100352], ptr=[513], x=[60303, 16], y=[512])
#
# Step 286:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60724], edge_index=[2, 100352], ptr=[513], x=[60724, 16], y=[512])
#
# Step 287:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60736], edge_index=[2, 100352], ptr=[513], x=[60736, 16], y=[512])
#
# Step 288:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60472], edge_index=[2, 100352], ptr=[513], x=[60472, 16], y=[512])
#
# Step 289:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60782], edge_index=[2, 100352], ptr=[513], x=[60782, 16], y=[512])
#
# Step 290:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60700], edge_index=[2, 100352], ptr=[513], x=[60700, 16], y=[512])
#
# Step 291:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60977], edge_index=[2, 100352], ptr=[513], x=[60977, 16], y=[512])
#
# Step 292:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61081], edge_index=[2, 100352], ptr=[513], x=[61081, 16], y=[512])
#
# Step 293:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60799], edge_index=[2, 100352], ptr=[513], x=[60799, 16], y=[512])
#
# Step 294:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61004], edge_index=[2, 100352], ptr=[513], x=[61004, 16], y=[512])
#
# Step 295:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60888], edge_index=[2, 100352], ptr=[513], x=[60888, 16], y=[512])
#
# Step 296:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60611], edge_index=[2, 100352], ptr=[513], x=[60611, 16], y=[512])
#
# Step 297:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60082], edge_index=[2, 100352], ptr=[513], x=[60082, 16], y=[512])
#
# Step 298:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60771], edge_index=[2, 100352], ptr=[513], x=[60771, 16], y=[512])
#
# Step 299:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61117], edge_index=[2, 100352], ptr=[513], x=[61117, 16], y=[512])
#
# Step 300:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60080], edge_index=[2, 100352], ptr=[513], x=[60080, 16], y=[512])
#
# Step 301:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60502], edge_index=[2, 100352], ptr=[513], x=[60502, 16], y=[512])
#
# Step 302:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61000], edge_index=[2, 100352], ptr=[513], x=[61000, 16], y=[512])
#
# Step 303:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60981], edge_index=[2, 100352], ptr=[513], x=[60981, 16], y=[512])
#
# Step 304:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60882], edge_index=[2, 100352], ptr=[513], x=[60882, 16], y=[512])
#
# Step 305:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61207], edge_index=[2, 100352], ptr=[513], x=[61207, 16], y=[512])
#
# Step 306:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60835], edge_index=[2, 100352], ptr=[513], x=[60835, 16], y=[512])
#
# Step 307:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60817], edge_index=[2, 100352], ptr=[513], x=[60817, 16], y=[512])
#
# Step 308:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60317], edge_index=[2, 100352], ptr=[513], x=[60317, 16], y=[512])
#
# Step 309:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[61161], edge_index=[2, 100352], ptr=[513], x=[61161, 16], y=[512])
#
# Step 310:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60622], edge_index=[2, 100352], ptr=[513], x=[60622, 16], y=[512])
# Step 311:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60146], edge_index=[2, 100352], ptr=[513], x=[60146, 16], y=[512])
#
# Step 312:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[60251], edge_index=[2, 100352], ptr=[513], x=[60251, 16], y=[512])
#
# Step 313:
# =====
# Number of graphs in current batch: 254
# Batch(batch=[30450], edge_index=[2, 49784], ptr=[255], x=[30450, 16], y=[254])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv,GENConv
from torch_geometric.nn import global_mean_pool

class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(5)
        self.conv1 = GCNConv(16, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        #self.conv1 = GENConv(12, hidden_channels)
        #self.conv2 = GENConv(hidden_channels, hidden_channels)
        #self.conv3 = GENConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)
        
    def forward(self, x, edge_index, batch):
        # Get node embeeding
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        
        # Readout alayer
        x = global_mean_pool(x, batch)
        
        # Out layer
        x = F.dropout(x, p=0.4, training=self.training)
        x = self.lin(x)
        return x
    
model = GCN(hidden_channels=256)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(16, 256)
#   (conv2): GCNConv(256, 256)
#   (conv3): GCNConv(256, 256)
#   (lin): Linear(in_features=256, out_features=2, bias=True)
# )

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
torch.cuda.set_device(1)
print('Current cuda device ID:',torch.cuda.current_device())
print('Current cuda device name:', torch.cuda.get_device_name())
# Out:
# cuda:1
# Current cuda device ID: 1
# Current cuda device name: Tesla V100-PCIE-32GB

# %%
# Train/test
model = GCN(hidden_channels=256)
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
loss_func = torch.nn.CrossEntropyLoss()

def to_device(data, device):
    return data.to(device, non_blocking=True)

def train():
    model.train()
    for data in train_loader:
        a = to_device(data.x, device)
        b = to_device(data.edge_index, device)
        c = to_device(data.batch, device)
        d = to_device(data.y, device)
        
        out = model(a, b, c)
        #print(out)
        
        loss = loss_func(out, d)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
def test(loader):
    model.eval()
    correct = 0
    aupr, auroc, loss=[], [], []
    for data in loader:
        a = to_device(data.x, device)
        b = to_device(data.edge_index, device)
        c = to_device(data.batch, device)
        d = to_device(data.y, device)
        
        out = model(a, b, c)
        prob = F.softmax(out, dim=1)
        
        # AUPR
        precision, recall, thresholds = precision_recall_curve(d.detach().cpu().clone().numpy(), prob[:,1].detach().cpu().clone().numpy())
        aupr.append(auc(recall, precision))
        
        # AUROC
        try:
            auroc.append(roc_auc_score(d.detach().cpu().clone().numpy(), prob[:,1].detach().cpu().clone().numpy()))
        except:
            pass
        
        # LOSS
        loss_ = loss_func(out, d)
        loss.append(loss_.detach().cpu().clone().numpy())
        
        # print(prob)
        
        pred = out.argmax(dim=1)
        correct += int((pred==d).sum())
        
    return correct/len(loader.dataset), np.nanmean(aupr), np.nanmean(auroc), np.nanmean(loss)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc
from sklearn.metrics import roc_auc_score

# %%
np.seterr(divide='ignore', invalid='ignore')
train_acc_, test_acc_, train_aupr_, test_aupr_, train_auroc_, test_auroc_ = [], [], [], [], [], []
for epoch in range(1, 200):
    train()
    train_acc, train_aupr, train_auroc, train_loss = test(train_loader)
    test_acc, test_aupr, test_auroc, test_loss = test(test_loader)
    
    train_acc_.append(train_acc)
    test_acc_.append(test_acc)
    train_aupr_.append(train_aupr)
    test_aupr_.append(test_aupr)
    train_auroc_.append(train_auroc)
    test_auroc_.append(test_auroc)
    
    print(f'Epoch:{epoch:03d}')
    print(f'Train::ACC:{train_acc} AUPR:{train_aupr} AUROC:{train_auroc} LOSS:{train_loss}')
    print(f'Test ::ACC:{test_acc} AUPR:{test_aupr} AUROC:{test_auroc} LOSS:{test_loss}')
    print()
    
    # print(f'Epoch:{epoch:03d},Train acc:{train_acc:.4f},Train aupr:{train_aupr:.4f},Train auroc:{train_auroc:.4f},Test acc:{test_acc:.4f},Test aupr:{test_aupr:.4f},Test auroc:{test_auroc:.4f}')
# Out:
# Epoch:001
# Train::ACC:0.8048788109851374 AUPR:0.4032429947993151 AUROC:0.6823279152425826 LOSS:0.4666190445423126
# Test ::ACC:0.8036 AUPR:0.4148729165290732 AUROC:0.6900809023889612 LOSS:0.4666746258735657
#
# Epoch:002
# Train::ACC:0.8090101126264079 AUPR:0.43054676549749843 AUROC:0.7126942526328717 LOSS:0.45545417070388794
# Test ::ACC:0.807925 AUPR:0.44145313081040477 AUROC:0.7181316770344256 LOSS:0.45561710000038147
#
# Epoch:003
# Train::ACC:0.8152289403617545 AUPR:0.44322016885153953 AUROC:0.7249053401516338 LOSS:0.44834104180336
# Test ::ACC:0.813375 AUPR:0.45407406480061163 AUROC:0.7297990238626457 LOSS:0.4478108882904053
#
# Epoch:004
# Train::ACC:0.8124414055175689 AUPR:0.46096189314502156 AUROC:0.737788480179833 LOSS:0.44289109110832214
# Test ::ACC:0.8112 AUPR:0.4642574768386935 AUROC:0.7378559813494865 LOSS:0.4450170695781708
#
# Epoch:005
# Train::ACC:0.8167977099713747 AUPR:0.4733536541179277 AUROC:0.7466119570255808 LOSS:0.4326411187648773
# Test ::ACC:0.815325 AUPR:0.479475158143198 AUROC:0.7497497164068845 LOSS:0.4331817030906677
#
# Epoch:006
# Train::ACC:0.8196977462218278 AUPR:0.4807075154609641 AUROC:0.7510721833681228 LOSS:0.428041934967041
# Test ::ACC:0.818275 AUPR:0.48673026255440954 AUROC:0.7523483152093189 LOSS:0.4294479489326477
#
# Epoch:007
# Train::ACC:0.8205727571594645 AUPR:0.4851263061968516 AUROC:0.7547388073300496 LOSS:0.42660075426101685
# Test ::ACC:0.81935 AUPR:0.4902202024104877 AUROC:0.7541801128963772 LOSS:0.42791396379470825
#
# Epoch:008
# Train::ACC:0.8216977712221403 AUPR:0.48901179768634917 AUROC:0.7577357412222799 LOSS:0.42565450072288513
# Test ::ACC:0.820675 AUPR:0.4954772240411116 AUROC:0.7586459941186071 LOSS:0.4258284270763397
#
# Epoch:009
# Train::ACC:0.8224977812222652 AUPR:0.4957782244778127 AUROC:0.7615717595476156 LOSS:0.4239659309387207
# Test ::ACC:0.8215 AUPR:0.49982350786317 AUROC:0.7598588754037391 LOSS:0.42656099796295166
#
# Epoch:010
# Train::ACC:0.8226602832535407 AUPR:0.502350950041185 AUROC:0.7653634493580281 LOSS:0.4195225238800049
# Test ::ACC:0.82175 AUPR:0.5044311889138587 AUROC:0.761425072799247 LOSS:0.4223041832447052
#
# Epoch:011
# Train::ACC:0.8241478018475231 AUPR:0.5065543329725606 AUROC:0.7674403715838183 LOSS:0.41788187623023987
# Test ::ACC:0.821375 AUPR:0.5059415505988448 AUROC:0.7634889588779421 LOSS:0.4202057421207428
#
# Epoch:012
# Train::ACC:0.8198164977062213 AUPR:0.5078495667156419 AUROC:0.7678238130685059 LOSS:0.42914071679115295
# Test ::ACC:0.8171 AUPR:0.5082367906237382 AUROC:0.764495514950502 LOSS:0.4318722188472748
#
# Epoch:013
# Train::ACC:0.8238102976287204 AUPR:0.5120256272702565 AUROC:0.7714562285419696 LOSS:0.4201728403568268
# Test ::ACC:0.8196 AUPR:0.5036415916373492 AUROC:0.7620108996528916 LOSS:0.42745769023895264
#
# Epoch:014
# Train::ACC:0.8260665758321979 AUPR:0.5179631934081008 AUROC:0.7741820185409057 LOSS:0.4133978486061096
# Test ::ACC:0.822775 AUPR:0.5104421906281573 AUROC:0.7674833371115023 LOSS:0.41943711042404175
#
# Epoch:015
# Train::ACC:0.8263353291916149 AUPR:0.5174854016478042 AUROC:0.7756890131039259 LOSS:0.4142046570777893
# Test ::ACC:0.822625 AUPR:0.5069202216649246 AUROC:0.7687559165684978 LOSS:0.4199073016643524
#
# Epoch:016
# Train::ACC:0.8279728496606208 AUPR:0.5226820647925844 AUROC:0.7777835981468986 LOSS:0.4119136333465576
# Test ::ACC:0.823075 AUPR:0.5141665914879098 AUROC:0.7685935350319584 LOSS:0.42087382078170776
#
# Epoch:017
# Train::ACC:0.8265915823947799 AUPR:0.5213925918000448 AUROC:0.7774594767812335 LOSS:0.41408199071884155
# Test ::ACC:0.8221 AUPR:0.5151500315305609 AUROC:0.7695566043918848 LOSS:0.4203087389469147
#
# Epoch:018
# Train::ACC:0.8271853398167477 AUPR:0.5245435869421837 AUROC:0.7796438753447897 LOSS:0.41577276587486267
# Test ::ACC:0.823425 AUPR:0.5170381037046884 AUROC:0.7724826270345443 LOSS:0.4215942621231079
#
# Epoch:019
# Train::ACC:0.8250603132539157 AUPR:0.5255677356768312 AUROC:0.7796294102539317 LOSS:0.41473904252052307
# Test ::ACC:0.82035 AUPR:0.5177886694502098 AUROC:0.7719719570871999 LOSS:0.4224684536457062
#
# Epoch:020
# Train::ACC:0.829772872160902 AUPR:0.5340928563501095 AUROC:0.7848736375628225 LOSS:0.4142214357852936
# Test ::ACC:0.824575 AUPR:0.5193249480606352 AUROC:0.7730319837466014 LOSS:0.42211034893989563
#
# Epoch:021
# Train::ACC:0.8288916111451393 AUPR:0.5362924996807318 AUROC:0.7870323741962024 LOSS:0.40715956687927246
# Test ::ACC:0.823575 AUPR:0.5247631444387545 AUROC:0.7773787874115271 LOSS:0.41585004329681396
#
# Epoch:022
# Train::ACC:0.8296416205202565 AUPR:0.5356048832787612 AUROC:0.7869688084523762 LOSS:0.4169190526008606
# Test ::ACC:0.824475 AUPR:0.520753030466392 AUROC:0.7736342970278227 LOSS:0.42593321204185486
#
# Epoch:023
# Train::ACC:0.8282666033325417 AUPR:0.543498991600365 AUROC:0.7910975473692106 LOSS:0.4081057608127594
# Test ::ACC:0.824025 AUPR:0.5223894002944544 AUROC:0.7749354021747061 LOSS:0.41715312004089355
#
# Epoch:024
# Train::ACC:0.8301353766922086 AUPR:0.5436266428178288 AUROC:0.791704200335926 LOSS:0.4112405478954315
# Test ::ACC:0.823425 AUPR:0.5210037049900463 AUROC:0.774278652082681 LOSS:0.423374742269516
#
# Epoch:025
# Train::ACC:0.8314041425517819 AUPR:0.5465130737038115 AUROC:0.7923907575711719 LOSS:0.4032582640647888
# Test ::ACC:0.82425 AUPR:0.5238291086124994 AUROC:0.7768802958474773 LOSS:0.4138677716255188
#
# Epoch:026
# Train::ACC:0.830054125676571 AUPR:0.541813337764375 AUROC:0.7911691764225911 LOSS:0.4086938798427582
# Test ::ACC:0.8228 AUPR:0.5229918190769965 AUROC:0.7752241110863788 LOSS:0.4206017553806305
#
# Epoch:027
# Train::ACC:0.830310378879736 AUPR:0.5517382382216106 AUROC:0.7960197722128161 LOSS:0.39966508746147156
# Test ::ACC:0.82495 AUPR:0.5252812996947348 AUROC:0.7781324226218485 LOSS:0.4128659963607788
#
# Epoch:028
# Train::ACC:0.8306478830985388 AUPR:0.5527632354386524 AUROC:0.7957257079456377 LOSS:0.3996197581291199
# Test ::ACC:0.8246 AUPR:0.5228127635317013 AUROC:0.7733452870359642 LOSS:0.4167573153972626
#
# Epoch:029
# Train::ACC:0.8267665845823072 AUPR:0.5529775551539712 AUROC:0.7973544983732714 LOSS:0.40212583541870117
# Test ::ACC:0.8208 AUPR:0.5214663669161836 AUROC:0.7775008849311245 LOSS:0.41675764322280884
#
# Epoch:030
# Train::ACC:0.8332354154426931 AUPR:0.559485725559707 AUROC:0.8009438722574136 LOSS:0.40137532353401184
# Test ::ACC:0.824025 AUPR:0.5287665776545657 AUROC:0.7811770134898878 LOSS:0.41555169224739075
#
# Epoch:031
# Train::ACC:0.8332229152864411 AUPR:0.5596506810156839 AUROC:0.8007704618361015 LOSS:0.39543813467025757
# Test ::ACC:0.82685 AUPR:0.530091744816476 AUROC:0.7792316499007518 LOSS:0.4145295321941376
#
# Epoch:032
# Train::ACC:0.8344166802085026 AUPR:0.5625559480400352 AUROC:0.8029279489801631 LOSS:0.39303067326545715
# Test ::ACC:0.824325 AUPR:0.5275051753484322 AUROC:0.7797203256648984 LOSS:0.41257742047309875
#
# Epoch:033
# Train::ACC:0.8268603357541969 AUPR:0.5648285057810519 AUROC:0.8042062214602439 LOSS:0.40184473991394043
# Test ::ACC:0.821025 AUPR:0.5267744184309772 AUROC:0.7796500117686784 LOSS:0.42065444588661194
#
# Epoch:034
# Train::ACC:0.8318541481768522 AUPR:0.5648407824429084 AUROC:0.8055032159684576 LOSS:0.3960329592227936
# Test ::ACC:0.82585 AUPR:0.5271185605546947 AUROC:0.7811224471381313 LOSS:0.41669580340385437
#
# Epoch:035
# Train::ACC:0.8361229515368942 AUPR:0.570452396345685 AUROC:0.8077550894169194 LOSS:0.39169424772262573
# Test ::ACC:0.82485 AUPR:0.5265370602512084 AUROC:0.780964315574698 LOSS:0.41292789578437805
#
# Epoch:036
# Train::ACC:0.83190414880186 AUPR:0.569327781622254 AUROC:0.8078922072520964 LOSS:0.4035300314426422
# Test ::ACC:0.8238 AUPR:0.5291042657682001 AUROC:0.7812471990780921 LOSS:0.4277651906013489
#
# Epoch:037
# Train::ACC:0.8347916848960611 AUPR:0.5741626114671093 AUROC:0.8102253887493012 LOSS:0.3944750428199768
# Test ::ACC:0.822275 AUPR:0.5288526680202382 AUROC:0.7791219488325066 LOSS:0.417656809091568
#
# Epoch:038
# Train::ACC:0.8376417205215065 AUPR:0.5794969299287195 AUROC:0.8128566417859867 LOSS:0.38663744926452637
# Test ::ACC:0.8252 AUPR:0.5281222421479886 AUROC:0.7809121045158378 LOSS:0.4157613515853882
#
# Epoch:039
# Train::ACC:0.8306041325516569 AUPR:0.5754372549985454 AUROC:0.8107315812381801 LOSS:0.39254701137542725
# Test ::ACC:0.8238 AUPR:0.5333445993379059 AUROC:0.7827157851952422 LOSS:0.4128671884536743
#
# Epoch:040
# Train::ACC:0.8380667258340729 AUPR:0.5769295267664647 AUROC:0.8115836851828137 LOSS:0.3866109848022461
# Test ::ACC:0.825025 AUPR:0.5266164512744882 AUROC:0.7805333310442691 LOSS:0.41158777475357056
# Epoch:041
# Train::ACC:0.8354416930211628 AUPR:0.5821501269556487 AUROC:0.8135186649307397 LOSS:0.3875111937522888
# Test ::ACC:0.825775 AUPR:0.5301394560593802 AUROC:0.7820044484047062 LOSS:0.41348299384117126
#
# Epoch:042
# Train::ACC:0.8386667333341666 AUPR:0.5841610745790669 AUROC:0.815739661873105 LOSS:0.38943225145339966
# Test ::ACC:0.8251 AUPR:0.5319805657926772 AUROC:0.7809665986954223 LOSS:0.4151720404624939
#
# Epoch:043
# Train::ACC:0.8346479330991637 AUPR:0.5843925255627519 AUROC:0.8152413096013961 LOSS:0.3861038088798523
# Test ::ACC:0.8257 AUPR:0.5321472155889433 AUROC:0.782168919718267 LOSS:0.4114278554916382
#
# Epoch:044
# Train::ACC:0.8388917361467019 AUPR:0.5878498802318995 AUROC:0.8180091730427315 LOSS:0.3852083086967468
# Test ::ACC:0.82425 AUPR:0.5338277498769882 AUROC:0.7816362026487401 LOSS:0.4134116470813751
#
# Epoch:045
# Train::ACC:0.8374854685683571 AUPR:0.5876511804832736 AUROC:0.8180619014739156 LOSS:0.3822564482688904
# Test ::ACC:0.8269 AUPR:0.5331184561753333 AUROC:0.7833208127963688 LOSS:0.40865060687065125
#
# Epoch:046
# Train::ACC:0.8384854810685134 AUPR:0.5901313868265782 AUROC:0.8188843386401361 LOSS:0.3814559578895569
# Test ::ACC:0.825825 AUPR:0.5292834142301588 AUROC:0.7801483209475623 LOSS:0.4114808738231659
#
# Epoch:047
# Train::ACC:0.8381979774747185 AUPR:0.5851563154675589 AUROC:0.8179896844812495 LOSS:0.3834659457206726
# Test ::ACC:0.82565 AUPR:0.531135595669717 AUROC:0.7842512235869189 LOSS:0.411982923746109
#
# Epoch:048
# Train::ACC:0.8278790984887311 AUPR:0.5887060513804595 AUROC:0.8195087098188131 LOSS:0.4009243845939636
# Test ::ACC:0.82115 AUPR:0.527556527881919 AUROC:0.7820899413596624 LOSS:0.43284326791763306
#
# Epoch:049
# Train::ACC:0.8382417280216002 AUPR:0.5910472700099696 AUROC:0.819282371040083 LOSS:0.3825578987598419
# Test ::ACC:0.8217 AUPR:0.5328915856256903 AUROC:0.7828441438071501 LOSS:0.4185944199562073
#
# Epoch:050
# Train::ACC:0.8405667570844636 AUPR:0.5955310899214488 AUROC:0.8220506819593433 LOSS:0.3795754313468933
# Test ::ACC:0.82555 AUPR:0.5320570386175311 AUROC:0.7805851702193642 LOSS:0.41229814291000366
#
# Epoch:051
# Train::ACC:0.8399979999749997 AUPR:0.5967157007073532 AUROC:0.8228849449539101 LOSS:0.3776470422744751
# Test ::ACC:0.825375 AUPR:0.5328340332367419 AUROC:0.7832819455859441 LOSS:0.4121309220790863
#
# Epoch:052
# Train::ACC:0.8396979962249528 AUPR:0.5956446977838888 AUROC:0.8224499095099389 LOSS:0.37971195578575134
# Test ::ACC:0.823575 AUPR:0.5357383533543211 AUROC:0.7838771550180786 LOSS:0.4149071276187897
#
# Epoch:053
# Train::ACC:0.8414542681783522 AUPR:0.5974118132032121 AUROC:0.822816778810155 LOSS:0.3854072391986847
# Test ::ACC:0.822425 AUPR:0.5282303031395508 AUROC:0.7798648182818297 LOSS:0.41566142439842224
#
# Epoch:054
# Train::ACC:0.8385417317716471 AUPR:0.599967762413277 AUROC:0.8254505721371205 LOSS:0.3774578869342804
# Test ::ACC:0.827325 AUPR:0.5415506491920519 AUROC:0.7873448189405744 LOSS:0.40575650334358215

# %%
import matplotlib.pyplot as plt
plt.plot(train_acc_)
plt.plot(test_acc_)
plt.plot(train_aupr_)
plt.show()
