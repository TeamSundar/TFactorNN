# %%
# Import package
import numpy as np
import random
from numpy.core.numeric import ones_like
from torch_geometric.data import Data, DataLoader
import torch
from tqdm import tqdm
from utils.debruijn import DeBruijnGraph

# %%
# Define tf and datapaths
TF = 'ctcf'

PATH_ = "/DATA/yogesh/encodeDream/%s/"%(TF)
# Using readlines()
file1 = open(PATH_+'processed_out/final_training.csv', 'r')
Lines = file1.readlines()

# %%
# Prepare Data
kmer, DATALIST = 4, []
for line in tqdm(Lines):
    onehot_x = []
    # get DNA sequence from the dummy file 
    s = line.strip().split(',')[0]
    d=DeBruijnGraph(s,kmer)    
    for node in d.x.flatten():
        one_hot_ = d.one_hot_encode(node).flatten()
        onehot_x.append(one_hot_.tolist())

    # Arrays to pytorch tensors
    onehot_x_tensor = torch.tensor(np.array(onehot_x), dtype=torch.float)
    onehot_edge_index_tensor = torch.tensor(d.edge_index, dtype=torch.long)
    
    # get the label from the data
    if line.strip().split(',')[1]=='U':
        y_tensor = torch.tensor(0)
    else:
        y_tensor = torch.tensor(1)

    # Add tensors to torch_geometric data object
    data = Data(x=onehot_x_tensor, edge_index=onehot_edge_index_tensor, y=y_tensor)

    DATALIST.append(data)

print('Datapoints:', len(DATALIST))

print('x_shape:', DATALIST[1].x.shape)
print('edge_index_shape:', DATALIST[1].edge_index.shape)
print()
# Out:
#   0%|          | 145294/47549176 [15:51<86:16:19, 152.63it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-556177b37b5f> in <module>()
#       5     # get DNA sequence from the dummy file
#       6     s = line.strip().split(',')[0]
# ----> 7     d=DeBruijnGraph(s,kmer)
#       8     for node in d.x.flatten():
#       9         one_hot_ = d.one_hot_encode(node).flatten()
#
# /home/yogesh/projects/202104_tfbind/notebooks/utils/debruijn.py in __init__(self, st, k)
#      57         self.x=x
#      58         self.edge_index=edge_index
# ---> 59         self.generate(st,k)
#
# /home/yogesh/projects/202104_tfbind/notebooks/utils/debruijn.py in generate(self, st, k)
#      19             print("insufficient size of string input returning empty graph")
#      20             return
# ---> 21         a,b,c= self.chop(st,k)
#      22         hash={b[0]:0}
#      23         j=1
#
# /home/yogesh/projects/202104_tfbind/notebooks/utils/debruijn.py in chop(self, st, k)
#       7         c=np.empty([0])
#       8         for i in range(0, len(st)-(k-1)):
# ----> 9             a=np.append(a,[st[i:i+k]],axis=0)
#      10             b=np.append(b,[st[i:i+k-1]],axis=0)
#      11             c=np.append(c,st[i+1:i+k])
#
# <__array_function__ internals> in append(*args, **kwargs)
#
# /home/yogesh/miniconda3/envs/kddcup/lib/python3.6/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4669         values = ravel(values)
#    4670         axis = arr.ndim-1
# -> 4671     return concatenate((arr, values), axis=axis)
#    4672
#    4673
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
temp_data = DATALIST[1]  # Get the first graph object.

print()
print(temp_data)
print('=============================================================')

# Gather some statistics about the first graph.
print(f'Number of nodes: {temp_data.num_nodes}')
print(f'Number of edges: {temp_data.num_edges}')
print(f'Average node degree: {temp_data.num_edges / temp_data.num_nodes:.2f}')
print(f'Contains self-loops: {temp_data.contains_self_loops()}')
print(f'Is undirected: {temp_data.is_undirected()}')
# Out:
# Data(edge_index=[2, 197], x=[60, 12], y=0)
# =============================================================
# Number of nodes: 60
# Number of edges: 197
# Average node degree: 3.28
# Contains self-loops: True
# Is undirected: False

# %%
# Split data
torch.manual_seed(11)
random.shuffle(DATALIST)

split_n = int(0.8*(len(DATALIST)))

train_dataset = DATALIST[:split_n]
test_dataset = DATALIST[split_n:]

print('Number of training graph:', len(train_dataset))
print('Number of testing graph:', len(test_dataset))
# Out:
# Number of training graph: 116235
# Number of testing graph: 29059

# %%
#####
from torch_geometric.data import DataLoader
train_loader = DataLoader(train_dataset, batch_size=512, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=512, shuffle=True)

for step, data in enumerate(train_loader):
    print(f'Step {step+1}:')
    print('=====')
    print(f'Number of graphs in current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27705], edge_index=[2, 100864], ptr=[513], x=[27705, 12], y=[512])
#
# Step 2:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27968], edge_index=[2, 100864], ptr=[513], x=[27968, 12], y=[512])
#
# Step 3:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27735], edge_index=[2, 100864], ptr=[513], x=[27735, 12], y=[512])
#
# Step 4:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27783], edge_index=[2, 100864], ptr=[513], x=[27783, 12], y=[512])
#
# Step 5:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27776], edge_index=[2, 100864], ptr=[513], x=[27776, 12], y=[512])
#
# Step 6:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28039], edge_index=[2, 100864], ptr=[513], x=[28039, 12], y=[512])
#
# Step 7:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27661], edge_index=[2, 100864], ptr=[513], x=[27661, 12], y=[512])
#
# Step 8:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27801], edge_index=[2, 100864], ptr=[513], x=[27801, 12], y=[512])
#
# Step 9:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27744], edge_index=[2, 100864], ptr=[513], x=[27744, 12], y=[512])
#
# Step 10:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28041], edge_index=[2, 100864], ptr=[513], x=[28041, 12], y=[512])
#
# Step 11:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27607], edge_index=[2, 100864], ptr=[513], x=[27607, 12], y=[512])
#
# Step 12:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27845], edge_index=[2, 100864], ptr=[513], x=[27845, 12], y=[512])
#
# Step 13:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28026], edge_index=[2, 100864], ptr=[513], x=[28026, 12], y=[512])
#
# Step 14:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27930], edge_index=[2, 100864], ptr=[513], x=[27930, 12], y=[512])
#
# Step 15:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27820], edge_index=[2, 100864], ptr=[513], x=[27820, 12], y=[512])
#
# Step 16:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27939], edge_index=[2, 100864], ptr=[513], x=[27939, 12], y=[512])
#
# Step 17:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27881], edge_index=[2, 100864], ptr=[513], x=[27881, 12], y=[512])
#
# Step 18:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27812], edge_index=[2, 100864], ptr=[513], x=[27812, 12], y=[512])
#
# Step 19:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27766], edge_index=[2, 100864], ptr=[513], x=[27766, 12], y=[512])
#
# Step 20:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27960], edge_index=[2, 100864], ptr=[513], x=[27960, 12], y=[512])
#
# Step 21:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28007], edge_index=[2, 100864], ptr=[513], x=[28007, 12], y=[512])
#
# Step 22:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27867], edge_index=[2, 100864], ptr=[513], x=[27867, 12], y=[512])
#
# Step 23:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27806], edge_index=[2, 100864], ptr=[513], x=[27806, 12], y=[512])
#
# Step 24:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27825], edge_index=[2, 100864], ptr=[513], x=[27825, 12], y=[512])
#
# Step 25:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27730], edge_index=[2, 100864], ptr=[513], x=[27730, 12], y=[512])
#
# Step 26:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27986], edge_index=[2, 100864], ptr=[513], x=[27986, 12], y=[512])
#
# Step 27:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27810], edge_index=[2, 100864], ptr=[513], x=[27810, 12], y=[512])
#
# Step 28:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27865], edge_index=[2, 100864], ptr=[513], x=[27865, 12], y=[512])
#
# Step 29:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27883], edge_index=[2, 100864], ptr=[513], x=[27883, 12], y=[512])
#
# Step 30:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27933], edge_index=[2, 100864], ptr=[513], x=[27933, 12], y=[512])
#
# Step 31:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27965], edge_index=[2, 100864], ptr=[513], x=[27965, 12], y=[512])
#
# Step 32:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27988], edge_index=[2, 100864], ptr=[513], x=[27988, 12], y=[512])
#
# Step 33:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27868], edge_index=[2, 100864], ptr=[513], x=[27868, 12], y=[512])
#
# Step 34:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27831], edge_index=[2, 100864], ptr=[513], x=[27831, 12], y=[512])
#
# Step 35:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27906], edge_index=[2, 100864], ptr=[513], x=[27906, 12], y=[512])
#
# Step 36:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27965], edge_index=[2, 100864], ptr=[513], x=[27965, 12], y=[512])
#
# Step 37:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27901], edge_index=[2, 100864], ptr=[513], x=[27901, 12], y=[512])
#
# Step 38:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27790], edge_index=[2, 100864], ptr=[513], x=[27790, 12], y=[512])
#
# Step 39:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27967], edge_index=[2, 100864], ptr=[513], x=[27967, 12], y=[512])
#
# Step 40:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27811], edge_index=[2, 100864], ptr=[513], x=[27811, 12], y=[512])
#
# Step 41:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27906], edge_index=[2, 100864], ptr=[513], x=[27906, 12], y=[512])
#
# Step 42:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27830], edge_index=[2, 100864], ptr=[513], x=[27830, 12], y=[512])
#
# Step 43:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27853], edge_index=[2, 100864], ptr=[513], x=[27853, 12], y=[512])
#
# Step 44:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27673], edge_index=[2, 100864], ptr=[513], x=[27673, 12], y=[512])
#
# Step 45:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27652], edge_index=[2, 100864], ptr=[513], x=[27652, 12], y=[512])
#
# Step 46:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27797], edge_index=[2, 100864], ptr=[513], x=[27797, 12], y=[512])
#
# Step 47:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27807], edge_index=[2, 100864], ptr=[513], x=[27807, 12], y=[512])
#
# Step 48:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27834], edge_index=[2, 100864], ptr=[513], x=[27834, 12], y=[512])
#
# Step 49:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27806], edge_index=[2, 100864], ptr=[513], x=[27806, 12], y=[512])
#
# Step 50:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27879], edge_index=[2, 100864], ptr=[513], x=[27879, 12], y=[512])
#
# Step 51:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28101], edge_index=[2, 100864], ptr=[513], x=[28101, 12], y=[512])
#
# Step 52:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27850], edge_index=[2, 100864], ptr=[513], x=[27850, 12], y=[512])
#
# Step 53:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27853], edge_index=[2, 100864], ptr=[513], x=[27853, 12], y=[512])
#
# Step 54:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27825], edge_index=[2, 100864], ptr=[513], x=[27825, 12], y=[512])
#
# Step 55:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27861], edge_index=[2, 100864], ptr=[513], x=[27861, 12], y=[512])
#
# Step 56:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27756], edge_index=[2, 100864], ptr=[513], x=[27756, 12], y=[512])
#
# Step 57:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27841], edge_index=[2, 100864], ptr=[513], x=[27841, 12], y=[512])
#
# Step 58:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27832], edge_index=[2, 100864], ptr=[513], x=[27832, 12], y=[512])
#
# Step 59:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27808], edge_index=[2, 100864], ptr=[513], x=[27808, 12], y=[512])
#
# Step 60:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27874], edge_index=[2, 100864], ptr=[513], x=[27874, 12], y=[512])
#
# Step 61:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27860], edge_index=[2, 100864], ptr=[513], x=[27860, 12], y=[512])
#
# Step 62:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28092], edge_index=[2, 100864], ptr=[513], x=[28092, 12], y=[512])
#
# Step 63:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27963], edge_index=[2, 100864], ptr=[513], x=[27963, 12], y=[512])
#
# Step 64:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27764], edge_index=[2, 100864], ptr=[513], x=[27764, 12], y=[512])
#
# Step 65:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27975], edge_index=[2, 100864], ptr=[513], x=[27975, 12], y=[512])
#
# Step 66:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27840], edge_index=[2, 100864], ptr=[513], x=[27840, 12], y=[512])
# Step 67:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28007], edge_index=[2, 100864], ptr=[513], x=[28007, 12], y=[512])
#
# Step 68:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27926], edge_index=[2, 100864], ptr=[513], x=[27926, 12], y=[512])
#
# Step 69:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27868], edge_index=[2, 100864], ptr=[513], x=[27868, 12], y=[512])
#
# Step 70:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27859], edge_index=[2, 100864], ptr=[513], x=[27859, 12], y=[512])
#
# Step 71:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27861], edge_index=[2, 100864], ptr=[513], x=[27861, 12], y=[512])
#
# Step 72:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27939], edge_index=[2, 100864], ptr=[513], x=[27939, 12], y=[512])
#
# Step 73:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27866], edge_index=[2, 100864], ptr=[513], x=[27866, 12], y=[512])
#
# Step 74:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27773], edge_index=[2, 100864], ptr=[513], x=[27773, 12], y=[512])
#
# Step 75:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27980], edge_index=[2, 100864], ptr=[513], x=[27980, 12], y=[512])
#
# Step 76:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27800], edge_index=[2, 100864], ptr=[513], x=[27800, 12], y=[512])
#
# Step 77:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27790], edge_index=[2, 100864], ptr=[513], x=[27790, 12], y=[512])
#
# Step 78:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27964], edge_index=[2, 100864], ptr=[513], x=[27964, 12], y=[512])
#
# Step 79:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28026], edge_index=[2, 100864], ptr=[513], x=[28026, 12], y=[512])
#
# Step 80:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27888], edge_index=[2, 100864], ptr=[513], x=[27888, 12], y=[512])
#
# Step 81:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27798], edge_index=[2, 100864], ptr=[513], x=[27798, 12], y=[512])
#
# Step 82:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27758], edge_index=[2, 100864], ptr=[513], x=[27758, 12], y=[512])
#
# Step 83:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28028], edge_index=[2, 100864], ptr=[513], x=[28028, 12], y=[512])
#
# Step 84:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27944], edge_index=[2, 100864], ptr=[513], x=[27944, 12], y=[512])
#
# Step 85:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27934], edge_index=[2, 100864], ptr=[513], x=[27934, 12], y=[512])
#
# Step 86:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27917], edge_index=[2, 100864], ptr=[513], x=[27917, 12], y=[512])
#
# Step 87:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27888], edge_index=[2, 100864], ptr=[513], x=[27888, 12], y=[512])
#
# Step 88:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27882], edge_index=[2, 100864], ptr=[513], x=[27882, 12], y=[512])
#
# Step 89:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27813], edge_index=[2, 100864], ptr=[513], x=[27813, 12], y=[512])
#
# Step 90:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27962], edge_index=[2, 100864], ptr=[513], x=[27962, 12], y=[512])
#
# Step 91:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27799], edge_index=[2, 100864], ptr=[513], x=[27799, 12], y=[512])
#
# Step 92:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28033], edge_index=[2, 100864], ptr=[513], x=[28033, 12], y=[512])
#
# Step 93:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28145], edge_index=[2, 100864], ptr=[513], x=[28145, 12], y=[512])
#
# Step 94:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27926], edge_index=[2, 100864], ptr=[513], x=[27926, 12], y=[512])
#
# Step 95:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28034], edge_index=[2, 100864], ptr=[513], x=[28034, 12], y=[512])
#
# Step 96:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27700], edge_index=[2, 100864], ptr=[513], x=[27700, 12], y=[512])
#
# Step 97:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27906], edge_index=[2, 100864], ptr=[513], x=[27906, 12], y=[512])
#
# Step 98:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27923], edge_index=[2, 100864], ptr=[513], x=[27923, 12], y=[512])
#
# Step 99:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27966], edge_index=[2, 100864], ptr=[513], x=[27966, 12], y=[512])
#
# Step 100:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27745], edge_index=[2, 100864], ptr=[513], x=[27745, 12], y=[512])
#
# Step 101:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27728], edge_index=[2, 100864], ptr=[513], x=[27728, 12], y=[512])
#
# Step 102:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27985], edge_index=[2, 100864], ptr=[513], x=[27985, 12], y=[512])
#
# Step 103:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28073], edge_index=[2, 100864], ptr=[513], x=[28073, 12], y=[512])
#
# Step 104:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28064], edge_index=[2, 100864], ptr=[513], x=[28064, 12], y=[512])
#
# Step 105:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28139], edge_index=[2, 100864], ptr=[513], x=[28139, 12], y=[512])
#
# Step 106:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27499], edge_index=[2, 100864], ptr=[513], x=[27499, 12], y=[512])
#
# Step 107:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28023], edge_index=[2, 100864], ptr=[513], x=[28023, 12], y=[512])
#
# Step 108:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27719], edge_index=[2, 100864], ptr=[513], x=[27719, 12], y=[512])
#
# Step 109:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27989], edge_index=[2, 100864], ptr=[513], x=[27989, 12], y=[512])
#
# Step 110:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27792], edge_index=[2, 100864], ptr=[513], x=[27792, 12], y=[512])
#
# Step 111:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27932], edge_index=[2, 100864], ptr=[513], x=[27932, 12], y=[512])
#
# Step 112:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27841], edge_index=[2, 100864], ptr=[513], x=[27841, 12], y=[512])
#
# Step 113:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27892], edge_index=[2, 100864], ptr=[513], x=[27892, 12], y=[512])
#
# Step 114:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27848], edge_index=[2, 100864], ptr=[513], x=[27848, 12], y=[512])
#
# Step 115:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27929], edge_index=[2, 100864], ptr=[513], x=[27929, 12], y=[512])
#
# Step 116:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27584], edge_index=[2, 100864], ptr=[513], x=[27584, 12], y=[512])
#
# Step 117:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27822], edge_index=[2, 100864], ptr=[513], x=[27822, 12], y=[512])
#
# Step 118:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27792], edge_index=[2, 100864], ptr=[513], x=[27792, 12], y=[512])
#
# Step 119:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27963], edge_index=[2, 100864], ptr=[513], x=[27963, 12], y=[512])
#
# Step 120:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27614], edge_index=[2, 100864], ptr=[513], x=[27614, 12], y=[512])
#
# Step 121:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27968], edge_index=[2, 100864], ptr=[513], x=[27968, 12], y=[512])
#
# Step 122:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27900], edge_index=[2, 100864], ptr=[513], x=[27900, 12], y=[512])
#
# Step 123:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27828], edge_index=[2, 100864], ptr=[513], x=[27828, 12], y=[512])
#
# Step 124:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27817], edge_index=[2, 100864], ptr=[513], x=[27817, 12], y=[512])
#
# Step 125:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27914], edge_index=[2, 100864], ptr=[513], x=[27914, 12], y=[512])
#
# Step 126:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27793], edge_index=[2, 100864], ptr=[513], x=[27793, 12], y=[512])
#
# Step 127:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27934], edge_index=[2, 100864], ptr=[513], x=[27934, 12], y=[512])
#
# Step 128:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27642], edge_index=[2, 100864], ptr=[513], x=[27642, 12], y=[512])
#
# Step 129:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27838], edge_index=[2, 100864], ptr=[513], x=[27838, 12], y=[512])
#
# Step 130:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27706], edge_index=[2, 100864], ptr=[513], x=[27706, 12], y=[512])
# Step 131:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28036], edge_index=[2, 100864], ptr=[513], x=[28036, 12], y=[512])
#
# Step 132:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27745], edge_index=[2, 100864], ptr=[513], x=[27745, 12], y=[512])
#
# Step 133:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27997], edge_index=[2, 100864], ptr=[513], x=[27997, 12], y=[512])
#
# Step 134:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27934], edge_index=[2, 100864], ptr=[513], x=[27934, 12], y=[512])
#
# Step 135:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27948], edge_index=[2, 100864], ptr=[513], x=[27948, 12], y=[512])
#
# Step 136:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27915], edge_index=[2, 100864], ptr=[513], x=[27915, 12], y=[512])
#
# Step 137:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27715], edge_index=[2, 100864], ptr=[513], x=[27715, 12], y=[512])
#
# Step 138:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27986], edge_index=[2, 100864], ptr=[513], x=[27986, 12], y=[512])
#
# Step 139:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27901], edge_index=[2, 100864], ptr=[513], x=[27901, 12], y=[512])
#
# Step 140:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27965], edge_index=[2, 100864], ptr=[513], x=[27965, 12], y=[512])
#
# Step 141:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27896], edge_index=[2, 100864], ptr=[513], x=[27896, 12], y=[512])
#
# Step 142:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27707], edge_index=[2, 100864], ptr=[513], x=[27707, 12], y=[512])
#
# Step 143:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27845], edge_index=[2, 100864], ptr=[513], x=[27845, 12], y=[512])
#
# Step 144:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27869], edge_index=[2, 100864], ptr=[513], x=[27869, 12], y=[512])
#
# Step 145:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27687], edge_index=[2, 100864], ptr=[513], x=[27687, 12], y=[512])
#
# Step 146:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27767], edge_index=[2, 100864], ptr=[513], x=[27767, 12], y=[512])
#
# Step 147:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27761], edge_index=[2, 100864], ptr=[513], x=[27761, 12], y=[512])
#
# Step 148:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27828], edge_index=[2, 100864], ptr=[513], x=[27828, 12], y=[512])
#
# Step 149:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27698], edge_index=[2, 100864], ptr=[513], x=[27698, 12], y=[512])
#
# Step 150:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27985], edge_index=[2, 100864], ptr=[513], x=[27985, 12], y=[512])
#
# Step 151:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27760], edge_index=[2, 100864], ptr=[513], x=[27760, 12], y=[512])
#
# Step 152:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27760], edge_index=[2, 100864], ptr=[513], x=[27760, 12], y=[512])
#
# Step 153:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28025], edge_index=[2, 100864], ptr=[513], x=[28025, 12], y=[512])
#
# Step 154:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27888], edge_index=[2, 100864], ptr=[513], x=[27888, 12], y=[512])
#
# Step 155:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28019], edge_index=[2, 100864], ptr=[513], x=[28019, 12], y=[512])
#
# Step 156:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27727], edge_index=[2, 100864], ptr=[513], x=[27727, 12], y=[512])
#
# Step 157:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27862], edge_index=[2, 100864], ptr=[513], x=[27862, 12], y=[512])
#
# Step 158:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27713], edge_index=[2, 100864], ptr=[513], x=[27713, 12], y=[512])
#
# Step 159:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27872], edge_index=[2, 100864], ptr=[513], x=[27872, 12], y=[512])
#
# Step 160:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27899], edge_index=[2, 100864], ptr=[513], x=[27899, 12], y=[512])
#
# Step 161:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27901], edge_index=[2, 100864], ptr=[513], x=[27901, 12], y=[512])
#
# Step 162:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27739], edge_index=[2, 100864], ptr=[513], x=[27739, 12], y=[512])
#
# Step 163:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27845], edge_index=[2, 100864], ptr=[513], x=[27845, 12], y=[512])
#
# Step 164:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27954], edge_index=[2, 100864], ptr=[513], x=[27954, 12], y=[512])
#
# Step 165:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27840], edge_index=[2, 100864], ptr=[513], x=[27840, 12], y=[512])
#
# Step 166:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28090], edge_index=[2, 100864], ptr=[513], x=[28090, 12], y=[512])
#
# Step 167:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27975], edge_index=[2, 100864], ptr=[513], x=[27975, 12], y=[512])
#
# Step 168:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27900], edge_index=[2, 100864], ptr=[513], x=[27900, 12], y=[512])
#
# Step 169:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27951], edge_index=[2, 100864], ptr=[513], x=[27951, 12], y=[512])
#
# Step 170:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27947], edge_index=[2, 100864], ptr=[513], x=[27947, 12], y=[512])
#
# Step 171:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27880], edge_index=[2, 100864], ptr=[513], x=[27880, 12], y=[512])
#
# Step 172:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27959], edge_index=[2, 100864], ptr=[513], x=[27959, 12], y=[512])
#
# Step 173:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27939], edge_index=[2, 100864], ptr=[513], x=[27939, 12], y=[512])
#
# Step 174:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27674], edge_index=[2, 100864], ptr=[513], x=[27674, 12], y=[512])
#
# Step 175:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27864], edge_index=[2, 100864], ptr=[513], x=[27864, 12], y=[512])
#
# Step 176:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27643], edge_index=[2, 100864], ptr=[513], x=[27643, 12], y=[512])
#
# Step 177:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27813], edge_index=[2, 100864], ptr=[513], x=[27813, 12], y=[512])
#
# Step 178:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27729], edge_index=[2, 100864], ptr=[513], x=[27729, 12], y=[512])
#
# Step 179:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28011], edge_index=[2, 100864], ptr=[513], x=[28011, 12], y=[512])
#
# Step 180:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27946], edge_index=[2, 100864], ptr=[513], x=[27946, 12], y=[512])
#
# Step 181:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27722], edge_index=[2, 100864], ptr=[513], x=[27722, 12], y=[512])
#
# Step 182:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28031], edge_index=[2, 100864], ptr=[513], x=[28031, 12], y=[512])
#
# Step 183:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27704], edge_index=[2, 100864], ptr=[513], x=[27704, 12], y=[512])
#
# Step 184:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28039], edge_index=[2, 100864], ptr=[513], x=[28039, 12], y=[512])
#
# Step 185:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28063], edge_index=[2, 100864], ptr=[513], x=[28063, 12], y=[512])
#
# Step 186:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27826], edge_index=[2, 100864], ptr=[513], x=[27826, 12], y=[512])
#
# Step 187:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27732], edge_index=[2, 100864], ptr=[513], x=[27732, 12], y=[512])
#
# Step 188:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27857], edge_index=[2, 100864], ptr=[513], x=[27857, 12], y=[512])
#
# Step 189:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27778], edge_index=[2, 100864], ptr=[513], x=[27778, 12], y=[512])
#
# Step 190:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28051], edge_index=[2, 100864], ptr=[513], x=[28051, 12], y=[512])
#
# Step 191:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27819], edge_index=[2, 100864], ptr=[513], x=[27819, 12], y=[512])
#
# Step 192:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27779], edge_index=[2, 100864], ptr=[513], x=[27779, 12], y=[512])
#
# Step 193:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27802], edge_index=[2, 100864], ptr=[513], x=[27802, 12], y=[512])
# Step 194:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27827], edge_index=[2, 100864], ptr=[513], x=[27827, 12], y=[512])
#
# Step 195:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27776], edge_index=[2, 100864], ptr=[513], x=[27776, 12], y=[512])
#
# Step 196:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27951], edge_index=[2, 100864], ptr=[513], x=[27951, 12], y=[512])
#
# Step 197:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27768], edge_index=[2, 100864], ptr=[513], x=[27768, 12], y=[512])
#
# Step 198:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27529], edge_index=[2, 100864], ptr=[513], x=[27529, 12], y=[512])
#
# Step 199:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27928], edge_index=[2, 100864], ptr=[513], x=[27928, 12], y=[512])
#
# Step 200:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27772], edge_index=[2, 100864], ptr=[513], x=[27772, 12], y=[512])
#
# Step 201:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27928], edge_index=[2, 100864], ptr=[513], x=[27928, 12], y=[512])
#
# Step 202:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27947], edge_index=[2, 100864], ptr=[513], x=[27947, 12], y=[512])
#
# Step 203:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27778], edge_index=[2, 100864], ptr=[513], x=[27778, 12], y=[512])
#
# Step 204:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27930], edge_index=[2, 100864], ptr=[513], x=[27930, 12], y=[512])
#
# Step 205:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27714], edge_index=[2, 100864], ptr=[513], x=[27714, 12], y=[512])
#
# Step 206:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27656], edge_index=[2, 100864], ptr=[513], x=[27656, 12], y=[512])
#
# Step 207:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27950], edge_index=[2, 100864], ptr=[513], x=[27950, 12], y=[512])
#
# Step 208:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27929], edge_index=[2, 100864], ptr=[513], x=[27929, 12], y=[512])
#
# Step 209:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28176], edge_index=[2, 100864], ptr=[513], x=[28176, 12], y=[512])
#
# Step 210:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27864], edge_index=[2, 100864], ptr=[513], x=[27864, 12], y=[512])
#
# Step 211:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27860], edge_index=[2, 100864], ptr=[513], x=[27860, 12], y=[512])
#
# Step 212:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28080], edge_index=[2, 100864], ptr=[513], x=[28080, 12], y=[512])
#
# Step 213:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27907], edge_index=[2, 100864], ptr=[513], x=[27907, 12], y=[512])
#
# Step 214:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27901], edge_index=[2, 100864], ptr=[513], x=[27901, 12], y=[512])
#
# Step 215:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27810], edge_index=[2, 100864], ptr=[513], x=[27810, 12], y=[512])
#
# Step 216:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27975], edge_index=[2, 100864], ptr=[513], x=[27975, 12], y=[512])
#
# Step 217:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27975], edge_index=[2, 100864], ptr=[513], x=[27975, 12], y=[512])
#
# Step 218:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27872], edge_index=[2, 100864], ptr=[513], x=[27872, 12], y=[512])
#
# Step 219:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27937], edge_index=[2, 100864], ptr=[513], x=[27937, 12], y=[512])
#
# Step 220:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27912], edge_index=[2, 100864], ptr=[513], x=[27912, 12], y=[512])
#
# Step 221:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27927], edge_index=[2, 100864], ptr=[513], x=[27927, 12], y=[512])
#
# Step 222:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28058], edge_index=[2, 100864], ptr=[513], x=[28058, 12], y=[512])
#
# Step 223:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27774], edge_index=[2, 100864], ptr=[513], x=[27774, 12], y=[512])
#
# Step 224:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27914], edge_index=[2, 100864], ptr=[513], x=[27914, 12], y=[512])
#
# Step 225:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27949], edge_index=[2, 100864], ptr=[513], x=[27949, 12], y=[512])
#
# Step 226:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[28133], edge_index=[2, 100864], ptr=[513], x=[28133, 12], y=[512])
#
# Step 227:
# =====
# Number of graphs in current batch: 512
# Batch(batch=[27856], edge_index=[2, 100864], ptr=[513], x=[27856, 12], y=[512])
#
# Step 228:
# =====
# Number of graphs in current batch: 11
# Batch(batch=[564], edge_index=[2, 2167], ptr=[12], x=[564, 12], y=[11])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv,GENConv
from torch_geometric.nn import global_mean_pool

class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super(GCN, self).__init__()
        torch.manual_seed(5)
        self.conv1 = GCNConv(12, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        #self.conv1 = GENConv(12, hidden_channels)
        #self.conv2 = GENConv(hidden_channels, hidden_channels)
        #self.conv3 = GENConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 2)
        
    def forward(self, x, edge_index, batch):
        # Get node embeeding
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        
        # Readout alayer
        x = global_mean_pool(x, batch)
        
        # Out layer
        x = F.dropout(x, p=0.4, training=self.training)
        x = self.lin(x)
        return x
    
model = GCN(hidden_channels=512)
print(model)
# Out:
# GCN(
#   (conv1): GCNConv(12, 512)
#   (conv2): GCNConv(512, 512)
#   (conv3): GCNConv(512, 512)
#   (lin): Linear(in_features=512, out_features=2, bias=True)
# )

# %%
device = torch.device("cuda:1" if torch.cuda.is_available() else "cpu")
print(device)
torch.cuda.set_device(1)
print('Current cuda device ID:',torch.cuda.current_device())
print('Current cuda device name:', torch.cuda.get_device_name())
# Out:
# cuda:1
# Current cuda device ID: 1
# Current cuda device name: Tesla V100-PCIE-32GB

# %%
# Train/test
model = GCN(hidden_channels=256)
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
loss_func = torch.nn.CrossEntropyLoss()

def to_device(data, device):
    return data.to(device, non_blocking=True)

def train():
    model.train()
    for data in train_loader:
        a = to_device(data.x, device)
        b = to_device(data.edge_index, device)
        c = to_device(data.batch, device)
        d = to_device(data.y, device)
        
        out = model(a, b, c)
        #print(out)
        
        loss = loss_func(out, d)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()
    
def test(loader):
    model.eval()
    correct = 0
    aupr=[]
    for data in loader:
        a = to_device(data.x, device)
        b = to_device(data.edge_index, device)
        c = to_device(data.batch, device)
        d = to_device(data.y, device)
        
        out = model(a, b, c)
        
        precision, recall, thresholds = precision_recall_curve(d.detach().cpu().clone().numpy(), out[:,1].detach().cpu().clone().numpy())
        aupr.append(auc(recall, precision))
        # print(aupr)
        
        pred = out.argmax(dim=1)
        correct += int((pred==d).sum())
        
    return correct/len(loader.dataset), np.nanmean(aupr)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import auc

# %%
np.seterr(divide='ignore', invalid='ignore')
train_, test_ = [], []
for epoch in range(1, 100):
    train()
    train_acc, train_aupr = test(train_loader)
    test_acc, test_aupr = test(test_loader)
    
    train_.append(train_acc)
    test_.append(test_acc)
    
    print(f'Epoch:{epoch:03d}, Train acc: {train_acc:.4f}, Train aupr: {train_aupr:.4f}, Test acc: {test_acc:.4f}, Test aupr: {test_aupr:.4f}')
# Out:
# Epoch:001, Train acc: 0.9944, Train aupr: 0.0080, Test acc: 0.9944, Test aupr: 0.0232
# Epoch:002, Train acc: 0.9944, Train aupr: 0.3239, Test acc: 0.9944, Test aupr: 0.3450
# Epoch:003, Train acc: 0.9944, Train aupr: 0.3229, Test acc: 0.9944, Test aupr: 0.3307
